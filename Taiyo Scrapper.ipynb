# %%
import requests
import pandas as pd
import lxml
from bs4 import BeautifulSoup

# %%
l=[]
class Scrapper:       
        
        def get_data(self):

            base_url="https://www.contractsfinder.service.gov.uk/Search/Results?&page="
            for page in range(1,50):
                r= requests.get(base_url+str(page)+"#dashboard_notices.html")
                c= r.content
                soup=BeautifulSoup(c,"lxml")
                all_data= soup.find_all("div",{"class":"search-result"})
                for item in all_data:
                    d={}
                    
                    d["Tender"]=item.find("a",{"class":["govuk-link" ,"search-result-rwh", "break-word"]}).text
                
                    d["Company"]=item.find("div",{"class":["search-result-sub-header", "wrap-test"]}).text
                    
                    d["Procurement"]=item.find_all("div",{"class":"search-result-entry"})[0].text.replace("Procurement stage"," ")
                    
                    d["Notice"]=item.find_all("div",{"class":"search-result-entry"})[1].text.replace("Notice status"," ")
                        
                    d["Location"]=item.find_all("div",{"class":"search-result-entry"})[3].text.replace("Contract location"," ")
                    
                    try:
                        d["Closing"]=item.find_all("div",{"class":"search-result-entry"})[2].text.replace("Closing"," ")
                    except:
                        d["Closing"]="None" 
                    try:
                        d["Value"]=item.find_all("div",{"class":"search-result-entry"})[4].text.replace("Contract value"," ")
                    except:
                        d["Value"]="None"  
                    try:
                        d["Date"]=item.find_all("div",{"class":"search-result-entry"})[5].text.replace("Publication date"," ")
                    except:
                        d["Date"]="None"    
                    l.append(d)
            return

# %%
obj=Scrapper()
obj.get_data()

# %%
df=pd.DataFrame(l)

# %%
#df.to_csv("data.csv",index=False)

# %%
df
# Out:
#                                                 Tender  \
# 0    RFQ Production of Grant Recipient Case Studies...
# 1                    PR2099-Growth Curve Peer Networks
# 2                                Online Legal Research
# 3    The Provision of Parachute Rigging Services to...
# 4    Supply of Coffee, Hot Drinks Machines and Prod...
# ..                                                 ...
# 975  704101451 - The Provision of Airfield Wildlife...
# 976  Service Concession Contract for the Provision ...
# 977                          Fleet management software
# 978  GB-Bath: GW4 Alliance Website User Research an...
# 979  3420/JN - Aviation Fuel Thermal Stability Test...
#
#                                               Company    Procurement  Notice  \
# 0                    CORNWALL DEVELOPMENT COMPANY LTD    Opportunity    Open
# 1    South East Midlands Local Enterprise Partnership    Opportunity    Open
# 2                       General Medical Council (GMC)    Opportunity    Open
# 3                                 Ministry of Defence    Opportunity    Open
# 4          Bournemouth Christchurch and Poole Council    Opportunity    Open
# ..                                                ...            ...     ...
# 975                               Ministry of Defence    Opportunity    Open
# 976                               Oxford City Council    Opportunity    Open
# 977              Bath and North East Somerset Council    Opportunity    Open
# 978                                University of Bath    Opportunity    Open
# 979                           UNIVERSITY OF SHEFFIELD    Opportunity    Open
#
#                              Location                    Closing  \
# 0                          South West     8 September 2022,  5pm
# 1      East Midlands, East of England    23 September 2022,  5pm
# 2                  North West, London    16 September 2022, 12pm
# 3                            OX25 3TQ    21 September 2022,  8am
# 4                          South West      10 October 2022,  2pm
# ..                                ...                        ...
# 975                        Any region     7 September 2022, 10am
# 976                           OX1 1DS     9 September 2022, 12pm
# 977                           England    26 September 2022, 12pm
# 978                        South West    19 September 2022,  2pm
# 979          Yorkshire and the Humber    23 September 2022, 12pm
#
#                      Value                                          Date
# 0                  £10,000    15 August 2022, last edited 22 August 2022
# 1                  £50,000                                22 August 2022
# 2            £0 to £75,000                                22 August 2022
# 3                 £150,000                                22 August 2022
# 4                 £550,000                                22 August 2022
# ..                     ...                                           ...
# 975             £2,880,000                                 9 August 2022
# 976               £220,000                                 9 August 2022
# 977                £70,000                                 9 August 2022
# 978    £50,000 to £100,000                                 9 August 2022
# 979               £300,000                                 9 August 2022
#
# [980 rows x 8 columns]
